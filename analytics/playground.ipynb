# %%
import numpy as np
import pandas as pd
from datetime import datetime
import calendar

# %%
periods = pd.period_range(start="2025-01-01", end="2025-12-31", freq="M")
monthly_rainfall = {"Sambalpur": np.random.standard_normal(12), "Bargarh": np.random.standard_normal(12),
                    "Balangir": np.random.standard_normal(12), "Kalahandi": np.random.standard_normal(12)}

# %%
rainfall_df = pd.DataFrame(monthly_rainfall)
rainfall_df.set_index(periods, inplace=True)
rainfall_df
# Out:
#          Sambalpur   Bargarh  Balangir  Kalahandi
# 2025-01   0.183833  0.247014 -0.575697   0.710666
# 2025-02   0.080835  0.132160  0.316223   0.461503
# 2025-03   0.313945  0.128679 -0.201560   0.311924
# 2025-04  -0.569805  1.201812  0.347801   0.417232
# 2025-05   1.390657  0.192816  1.236806   0.274739
# 2025-06   0.937847 -1.027381 -0.316351  -1.510165
# 2025-07  -1.066599  0.102771 -2.570399  -0.674817
# 2025-08  -0.434470  0.875705 -0.510424   0.992280
# 2025-09  -0.332091 -0.170982  1.112050   0.394720
# 2025-10   1.644419 -0.299576 -0.012528   1.212153
# 2025-11  -0.529610 -0.941677 -0.518331   0.685221
# 2025-12   0.613456  0.870427  0.721407  -0.167890

# %%
rainfall_df.plot()
# Out:
# <AxesSubplot:>
